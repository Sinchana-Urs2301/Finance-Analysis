# %% [markdown]
# ## Importing required librarirs for the analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Importing data into read CSV file

# %%
data = pd.read_csv("C:/Users/sinch/Downloads/European_Bank.csv", encoding="ISO-8859-1")

# %% [markdown]
# #### Understanding our data

# %%
data.head(10)
# Out:
#    Year  CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0  2025    15634602  Hargrave          619    France  Female   42       2
# 1  2025    15647311      Hill          608     Spain  Female   41       1
# 2  2025    15619304      Onio          502    France  Female   42       8
# 3  2025    15701354      Boni          699    France  Female   39       1
# 4  2025    15737888  Mitchell          850     Spain  Female   43       2
# 5  2025    15574012       Chu          645     Spain    Male   44       8
# 6  2025    15592531  Bartlett          822    France    Male   50       7
# 7  2025    15656148    Obinna          376   Germany  Female   29       4
# 8  2025    15792365        He          501    France    Male   44       4
# 9  2025    15592389        H?          684    France    Male   27       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# ...

# %%
data.shape
# Out:
# (10000, 14)

# %%
###### From the data we have observed that they have 10000 columns and 14 rows.
###### Which represents the 10000 customers of European bank and their details which is present in rows like CustomerId, Surname, CreditScore, Geography, Gender Age Tenure, Balance, NumOfProducts, Har
